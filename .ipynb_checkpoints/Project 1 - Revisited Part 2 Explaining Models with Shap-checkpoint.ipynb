# %% [markdown]
# # Global Explanations
#
# ## Imports

# %%
import joblib, os

import pandas as pd
import numpy as np

# %% [markdown]
# # Loading Joblib

# %%
# Load the joblib file stored in the models folder
fname = 'best-models.joblib'
loaded_joblib = joblib.load(fname)

# Preview the contents of the loaded joblib objects
loaded_joblib.keys()
# Out:
# dict_keys(['preprocessor', 'X_train', 'y_train', 'X_test', 'y_test', 'LinearRegression', 'RandomForestRegressor', 'TunedRandomForestRegressor'])

# %%
X_train = loaded_joblib['X_train']
X_test = loaded_joblib['X_test']
y_train = loaded_joblib['y_train']
y_test = loaded_joblib['y_test']

preprocessor = loaded_joblib['preprocessor']
LinearRegression = loaded_joblib['LinearRegression']
RandomForestRegressor = loaded_joblib['RandomForestRegressor']
TunedRandomForestRegressor = loaded_joblib['TunedRandomForestRegressor']

# Verify
X_train.head()
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 4776     0.827485        -0.712775  1.828109                   1.327849
# 7510     0.566644        -1.291052  0.603369                   1.327849
# 5828    -0.121028         1.813319  0.244541                   0.136187
# 5327    -1.158464        -1.004931 -0.952591                   0.732018
# 4810     1.538870        -0.965484 -0.336460                   0.493686
#
#       Item_Type_Baking Goods  Item_Type_Breads  Item_Type_Breakfast  \
# 4776                     0.0               0.0                  0.0
# 7510                     0.0               0.0                  0.0
# 5828                     0.0               0.0                  0.0
# 5327                     1.0               0.0                  0.0
# 4810                     0.0               0.0                  0.0
#
#       Item_Type_Canned  Item_Type_Dairy  Item_Type_Frozen Foods  ...  \
# ...

# %%
# recreate X_train_df and X_test_df
preprocessor.fit(X_train)
feature_names = preprocessor.get_feature_names_out()

X_train_df = pd.DataFrame(preprocessor.transform(X_train), 
                          columns = feature_names, 
                          index = X_train.index)

X_test_df = pd.DataFrame(preprocessor.transform(X_test), 
                         columns = feature_names, 
                         index = X_test.index)
X_test_df.head(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Item_Type'
#
# The above exception was the direct cause of the following exception:
#
# ...
